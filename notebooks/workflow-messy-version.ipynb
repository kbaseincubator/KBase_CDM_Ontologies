# %% [markdown]
# ## CDM ONTOLOGIES WORKFLOW

# %% [markdown]
# ### Full workflow

# %%
# %%time
import sys
import os
# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
# Import all required functions
from analyze_core_ontologies import analyze_core_ontologies
import analyze_non_core_ontologies
from create_pseudo_base_ontology import create_pseudo_base_ontologies
from merge_ontologies import merge_ontologies
from create_semantic_sql_db import create_semantic_sql_db
from extract_sql_tables_to_tsv import extract_sql_tables_to_tsv

# Print workflow start
print("Starting CDM Ontologies Workflow...")

print("\n1. Analyzing Core Ontologies...")
analyze_core_ontologies(repo_path)

print("\n2. Analyzing Non-Core Ontologies...")
analyze_non_core_ontologies.analyze_non_core_ontologies(repo_path)

print("\n3. Creating Pseudo Base Ontologies...")
create_pseudo_base_ontologies(repo_path)

print("\n4. Merging Ontologies...")
if not merge_ontologies(repo_path):
    raise Exception("Ontology merge failed")

print("\n5. Creating Semantic SQL Database...")
if not create_semantic_sql_db(repo_path):
    raise Exception("Database creation failed")

print("\n6. Extracting SQL Tables to TSV...")
if not extract_sql_tables_to_tsv(repo_path):
    raise Exception("TSV extraction failed")

print("\nWorkflow completed successfully!")
# Out:
# Starting CDM Ontologies Workflow...
#
# 1. Analyzing Core Ontologies...
#
# Analysis Results:
# Skipping download, envo.owl already present
#
# File: envo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/envo.owl
#   Own terms: 4385
#   External terms: 3043
#   Classification: Non-Base. Base version available in OBO Foundry: http://purl.obolibrary.org/obo/envo/envo-base.owl.
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 2984
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
#     http://purl.obolibrary.org/obo/BFO_0000006
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/ENVO_00000000
#     http://purl.obolibrary.org/obo/ENVO_00000001
#     http://purl.obolibrary.org/obo/ENVO_00000002
#     http://purl.obolibrary.org/obo/ENVO_00000003
#     http://purl.obolibrary.org/obo/ENVO_00000004
#   First 5 external terms:
#     http://geneontology.org/foo/applies-pattern
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
# Skipping download, go.owl already present
#
# File: go.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/go.owl
#   Own terms: 51567
#   External terms: 73
#   Classification: Non-Base. Base version available in OBO Foundry: http://purl.obolibrary.org/obo/go/go-base.owl.
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 53
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000066
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000233
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/GO_0000001
#     http://purl.obolibrary.org/obo/GO_0000002
#     http://purl.obolibrary.org/obo/GO_0000003
#     http://purl.obolibrary.org/obo/GO_0000004
#     http://purl.obolibrary.org/obo/GO_0000005
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000066
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
# Skipping download, ncbitaxon.owl already present
#
# File: ncbitaxon.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/ncbitaxon.owl
#   Own terms: 2594866
#   External terms: 31
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 28
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/OMO_0003003
#     http://purl.obolibrary.org/obo/OMO_0003006
#     http://purl.obolibrary.org/obo/OMO_0003007
#     http://purl.obolibrary.org/obo/OMO_0003012
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/NCBITaxon#_species_group
#     http://purl.obolibrary.org/obo/NCBITaxon#_species_subgroup
#     http://purl.obolibrary.org/obo/NCBITaxon#_taxonomic_rank
#     http://purl.obolibrary.org/obo/NCBITaxon_1
#     http://purl.obolibrary.org/obo/NCBITaxon_10
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/OMO_0003003
#     http://purl.obolibrary.org/obo/OMO_0003006
#     http://purl.obolibrary.org/obo/OMO_0003007
#     http://purl.obolibrary.org/obo/OMO_0003012
# Skipping download, chebi.owl already present
#
# File: chebi.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/chebi.owl
#   Own terms: 220224
#   External terms: 48
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 29
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/RO_0000087
#     http://purl.obolibrary.org/obo/chebi#1_STAR
#     http://purl.obolibrary.org/obo/chebi#2_STAR
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/CHEBI_1
#     http://purl.obolibrary.org/obo/CHEBI_10
#     http://purl.obolibrary.org/obo/CHEBI_100
#     http://purl.obolibrary.org/obo/CHEBI_1000
#     http://purl.obolibrary.org/obo/CHEBI_10000
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000231
#     http://purl.obolibrary.org/obo/IAO_0100001
#     http://purl.obolibrary.org/obo/RO_0000087
#
# Analysis complete!
#
# 2. Analyzing Non-Core Ontologies...
#
# Processing external terms from core ontologies...
# Downloading regular version of po...
# Successfully downloaded: po.owl
# Downloading base version of caro...
# Successfully downloaded: caro-base.owl
# Downloading base version of fao...
# Successfully downloaded: fao-base.owl
# Downloading base version of uberon...
# Successfully downloaded: uberon-base.owl
# Downloading base version of cl...
# Successfully downloaded: cl-base.owl
# Downloading base version of obi...
# Successfully downloaded: obi-base.owl
# Downloading base version of pato...
# Successfully downloaded: pato-base.owl
# Downloading base version of ro...
# Successfully downloaded: ro-base.owl
# Downloading regular version of bfo...
# Successfully downloaded: bfo.owl
# Downloading regular version of iao...
# Successfully downloaded: iao.owl
# Downloading base version of pco...
# Successfully downloaded: pco-base.owl
# Downloading regular version of foodon...
# Successfully downloaded: foodon.owl
# Downloading regular version of omo...
# Successfully downloaded: omo.owl
#
# Updating ontologies.txt...
#
# Processing Additional OBO Foundry, PyOBO and In-house ontologies...
# Downloading uo.owl...
# Successfully downloaded: uo.owl
# Downloading eccode.owl.gz...
# Successfully downloaded and decompressed: eccode.owl
# Downloading pfam.owl...
# Successfully downloaded: pfam.owl
# Downloading rhea.owl.gz...
# Successfully downloaded and decompressed: rhea.owl
#
# Analyzing non-core ontologies...
#
# Analyzing non-core ontologies:
#
# File: bfo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/bfo.owl
#   Own terms: 37
#   External terms: 21
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 14
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000111
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
#     http://purl.obolibrary.org/obo/IAO_0000117
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
#     http://purl.obolibrary.org/obo/BFO_0000006
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000111
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
#     http://purl.obolibrary.org/obo/IAO_0000117
#
# File: eccode.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/eccode.owl
#   Own terms: 0
#   External terms: 249359
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 8743
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0100001
#     http://purl.obolibrary.org/obo/RO_0002327
#     http://purl.obolibrary.org/obo/RO_0002351
#     http://purl.obolibrary.org/obo/eccode.owl
#     http://www.geneontology.org/formats/oboInOwl#hasExactSynonym
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/GO_0000010
#     http://purl.obolibrary.org/obo/GO_0000016
#     http://purl.obolibrary.org/obo/GO_0000034
#     http://purl.obolibrary.org/obo/GO_0000048
#     http://purl.obolibrary.org/obo/GO_0000121
#
# File: foodon.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/foodon.owl
#   Own terms: 28193
#   External terms: 10746
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 10699
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/AGRO_00000025
#     http://purl.obolibrary.org/obo/AGRO_00000322
#     http://purl.obolibrary.org/obo/AGRO_00000360
#     http://purl.obolibrary.org/obo/AGRO_00000363
#     http://purl.obolibrary.org/obo/AGRO_00002071
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/FOODON_00000000
#     http://purl.obolibrary.org/obo/FOODON_00000015
#     http://purl.obolibrary.org/obo/FOODON_00000070
#     http://purl.obolibrary.org/obo/FOODON_00000071
#     http://purl.obolibrary.org/obo/FOODON_00000072
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/AGRO_00000025
#     http://purl.obolibrary.org/obo/AGRO_00000322
#     http://purl.obolibrary.org/obo/AGRO_00000360
#     http://purl.obolibrary.org/obo/AGRO_00000363
#     http://purl.obolibrary.org/obo/AGRO_00002071
#
# File: iao.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/iao.owl
#   Own terms: 283
#   External terms: 130
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 101
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000008
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000032
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000033
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000522
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000524
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/IAO_0000001
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000003
#     http://purl.obolibrary.org/obo/IAO_0000004
#     http://purl.obolibrary.org/obo/IAO_0000005
#   First 5 external terms:
#     http://protege.stanford.edu/plugins/owl/protege#defaultLanguage
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000008
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000032
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000033
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000522
#
# File: omo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/omo.owl
#   Own terms: 18
#   External terms: 107
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 84
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000027
#     http://purl.obolibrary.org/obo/IAO_0000030
#     http://purl.obolibrary.org/obo/IAO_0000078
#     http://purl.obolibrary.org/obo/IAO_0000102
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/OMO_0001000
#     http://purl.obolibrary.org/obo/OMO_0001001
#     http://purl.obolibrary.org/obo/OMO_0001002
#     http://purl.obolibrary.org/obo/OMO_0002000
#     http://purl.obolibrary.org/obo/OMO_0003000
#   First 5 external terms:
#     http://protege.stanford.edu/plugins/owl/protege#defaultLanguage
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000027
#     http://purl.obolibrary.org/obo/IAO_0000030
#     http://purl.obolibrary.org/obo/IAO_0000078
#
# File: pfam.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/pfam.owl
#   Own terms: 0
#   External terms: 24553
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 23798
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/pfam.owl
#     http://purl.obolibrary.org/obo/pfam_PF00001
#     http://purl.obolibrary.org/obo/pfam_PF00002
#     http://purl.obolibrary.org/obo/pfam_PF00003
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/pfam.clan_CL0001
#     http://purl.obolibrary.org/obo/pfam.clan_CL0003
#     http://purl.obolibrary.org/obo/pfam.clan_CL0004
#     http://purl.obolibrary.org/obo/pfam.clan_CL0005
#
# File: po.owl
#   Has imports: Yes
#   Ontology IRI: http://purl.obolibrary.org/obo/po.owl
#   Own terms: 1996
#   External terms: 67
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 50
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/IAO_0000115
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/PO_0000001
#     http://purl.obolibrary.org/obo/PO_0000002
#     http://purl.obolibrary.org/obo/PO_0000003
#     http://purl.obolibrary.org/obo/PO_0000004
#     http://purl.obolibrary.org/obo/PO_0000005
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/IAO_0000115
#
# File: rhea.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/rhea.owl
#   Own terms: 0
#   External terms: 323609
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 67894
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/RO_0000056
#     http://purl.obolibrary.org/obo/RO_0000057
#     http://purl.obolibrary.org/obo/RO_0002233
#     http://purl.obolibrary.org/obo/RO_0002234
#     http://purl.obolibrary.org/obo/RO_0002327
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/CHEBI_100
#     http://purl.obolibrary.org/obo/CHEBI_10015
#     http://purl.obolibrary.org/obo/CHEBI_10023
#     http://purl.obolibrary.org/obo/CHEBI_10036
#     http://purl.obolibrary.org/obo/CHEBI_10106
#
# File: uo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/uo.owl
#   Own terms: 572
#   External terms: 5
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 1
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/uo.owl
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/UO_0000000
#     http://purl.obolibrary.org/obo/UO_0000001
#     http://purl.obolibrary.org/obo/UO_0000002
#     http://purl.obolibrary.org/obo/UO_0000003
#     http://purl.obolibrary.org/obo/UO_0000004
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/has_prefix
#     http://purl.obolibrary.org/obo/is_unit_of
#     http://purl.obolibrary.org/obo/uo.owl
#     http://www.geneontology.org/formats/oboInOwl#hasExactSynonym
#     http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym
#
# Analysis complete!
#
# 3. Creating Pseudo Base Ontologies...
# Using ROBOT at: /cdm_shared_workspace/user_shared_workspace/Jose/install_stuff/robot/robot
# Processing uo.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/uo.owl --base-iri http://purl.obolibrary.org/obo/HAS_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
# Created base version for uo.owl: uo-base.owl
# Processing omo.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/omo.owl --base-iri http://purl.obolibrary.org/obo/IAO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
# Created base version for omo.owl: omo-base.owl
# Processing iao.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/iao.owl --base-iri http://purl.obolibrary.org/obo/BFO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
# Created base version for iao.owl: iao-base.owl
# Processing bfo.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/bfo.owl --base-iri http://purl.obolibrary.org/obo/BFO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
# Created base version for bfo.owl: bfo-base.owl
# Processing foodon.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/foodon.owl --base-iri http://purl.obolibrary.org/obo/COB_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
# Created base version for foodon.owl: foodon-base.owl
# Copying PyOBO ontology to main directory: eccode.owl
# Processing po.owl...
# Executing command:
# robot remove --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/po.owl --base-iri http://purl.obolibrary.org/obo/IAO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
# Created base version for po.owl: po-base.owl
# Copying PyOBO ontology to main directory: rhea.owl
# Copying PyOBO ontology to main directory: pfam.owl
#
# Processing complete!
#
# 4. Merging Ontologies...
# Using ROBOT at: /cdm_shared_workspace/user_shared_workspace/Jose/install_stuff/robot/robot
# Looking for ontology files in: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl
# Found 25 ontology files:
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl
# Created list of merged ontologies at: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/CDM_merged_ontologies.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/CDM_merged_ontologies.owl

# %% [markdown]
# ### Worflow in seperate steps

# %% [markdown]
# #### Analyze and Download Core Ontologies

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the analysis
from analyze_core_ontologies import analyze_core_ontologies

# Run the analysis
analyze_core_ontologies(repo_path)
# Out:
# Analysis Results:
# Downloading envo.owl...
# Successfully downloaded: envo.owl
#
# File: envo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/envo.owl
#   Own terms: 4514
#   External terms: 2858
#   Classification: Non-Base. Base version available in OBO Foundry: http://purl.obolibrary.org/obo/envo/envo-base.owl.
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 2807
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
#     http://purl.obolibrary.org/obo/BFO_0000006
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/ENVO_00000000
#     http://purl.obolibrary.org/obo/ENVO_00000001
#     http://purl.obolibrary.org/obo/ENVO_00000002
#     http://purl.obolibrary.org/obo/ENVO_00000003
#     http://purl.obolibrary.org/obo/ENVO_00000004
#   First 5 external terms:
#     http://geneontology.org/foo/applies-pattern
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
# Downloading go.owl...
# Successfully downloaded: go.owl
#
# File: go.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/go.owl
#   Own terms: 51567
#   External terms: 73
#   Classification: Non-Base. Base version available in OBO Foundry: http://purl.obolibrary.org/obo/go/go-base.owl.
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 53
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000066
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000233
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/GO_0000001
#     http://purl.obolibrary.org/obo/GO_0000002
#     http://purl.obolibrary.org/obo/GO_0000003
#     http://purl.obolibrary.org/obo/GO_0000004
#     http://purl.obolibrary.org/obo/GO_0000005
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000066
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
# Downloading ncbitaxon.owl...
# Successfully downloaded: ncbitaxon.owl
#
# File: ncbitaxon.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/ncbitaxon.owl
#   Own terms: 2613937
#   External terms: 31
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 28
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/OMO_0003003
#     http://purl.obolibrary.org/obo/OMO_0003006
#     http://purl.obolibrary.org/obo/OMO_0003007
#     http://purl.obolibrary.org/obo/OMO_0003012
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/NCBITaxon#_species_group
#     http://purl.obolibrary.org/obo/NCBITaxon#_species_subgroup
#     http://purl.obolibrary.org/obo/NCBITaxon#_taxonomic_rank
#     http://purl.obolibrary.org/obo/NCBITaxon_1
#     http://purl.obolibrary.org/obo/NCBITaxon_10
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/OMO_0003003
#     http://purl.obolibrary.org/obo/OMO_0003006
#     http://purl.obolibrary.org/obo/OMO_0003007
#     http://purl.obolibrary.org/obo/OMO_0003012
# Downloading chebi.owl...
# Successfully downloaded: chebi.owl
#
# File: chebi.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/chebi.owl
#   Own terms: 220816
#   External terms: 48
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 29
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/RO_0000087
#     http://purl.obolibrary.org/obo/chebi#1_STAR
#     http://purl.obolibrary.org/obo/chebi#2_STAR
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/CHEBI_1
#     http://purl.obolibrary.org/obo/CHEBI_10
#     http://purl.obolibrary.org/obo/CHEBI_100
#     http://purl.obolibrary.org/obo/CHEBI_1000
#     http://purl.obolibrary.org/obo/CHEBI_10000
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000231
#     http://purl.obolibrary.org/obo/IAO_0100001
#     http://purl.obolibrary.org/obo/RO_0000087
#
# Analysis complete!
# CPU times: user 3min 14s, sys: 29.7 s, total: 3min 44s
# Wall time: 8min 11s

# %% [markdown]
# #### Analyze and Download Non-Core Ontologies

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the analysis
import analyze_non_core_ontologies

# Run the analysis
analyze_non_core_ontologies.analyze_non_core_ontologies(repo_path)
# Out:
# Processing external terms from core ontologies...
# Downloading base version of ro...
# Successfully downloaded: ro-base.owl
# Downloading base version of pato...
# Successfully downloaded: pato-base.owl
# Downloading base version of obi...
# Successfully downloaded: obi-base.owl
# Downloading base version of fao...
# Successfully downloaded: fao-base.owl
# Downloading regular version of po...
# Successfully downloaded: po.owl
# Downloading base version of pco...
# Successfully downloaded: pco-base.owl
# Downloading regular version of iao...
# Successfully downloaded: iao.owl
# Downloading base version of uberon...
# Successfully downloaded: uberon-base.owl
# Downloading regular version of omo...
# Successfully downloaded: omo.owl
# Downloading regular version of bfo...
# Successfully downloaded: bfo.owl
# Downloading regular version of foodon...
# Successfully downloaded: foodon.owl
#
# Updating ontologies.txt...
#
# Processing Additional OBO Foundry, PyOBO and In-house ontologies...
# Downloading uo.owl...
# Successfully downloaded: uo.owl
# Downloading taxrank.owl...
# Successfully downloaded: taxrank.owl
# Downloading so.owl...
# Successfully downloaded: so.owl
# Downloading gtdb.owl...
# Successfully downloaded: gtdb.owl
# Downloading eccode.owl.gz...
# Successfully downloaded and decompressed: eccode.owl
# Downloading pfam.owl...
# Successfully downloaded: pfam.owl
# Downloading rhea.owl.gz...
# Successfully downloaded and decompressed: rhea.owl
# Downloading credit.owl...
# Successfully downloaded: credit.owl
# Downloading ror.owl.gz...
# Successfully downloaded and decompressed: ror.owl
# Downloading interpro.owl...
# Successfully downloaded: interpro.owl
#
# Analyzing non-core ontologies...
#
# Analyzing non-core ontologies:
#
# File: bfo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/bfo.owl
#   Own terms: 37
#   External terms: 21
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 14
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000111
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
#     http://purl.obolibrary.org/obo/IAO_0000117
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/BFO_0000001
#     http://purl.obolibrary.org/obo/BFO_0000002
#     http://purl.obolibrary.org/obo/BFO_0000003
#     http://purl.obolibrary.org/obo/BFO_0000004
#     http://purl.obolibrary.org/obo/BFO_0000006
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000111
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000116
#     http://purl.obolibrary.org/obo/IAO_0000117
#
# File: credit.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/credit/credit.ofn
#   Own terms: 0
#   External terms: 19
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 15
#   First 5 external terms that are subject of triples:
#     https://credit.niso.org/contributor-roles/conceptualization
#     https://credit.niso.org/contributor-roles/data-curation
#     https://credit.niso.org/contributor-roles/formal-analysis
#     https://credit.niso.org/contributor-roles/funding-acquisition
#     https://credit.niso.org/contributor-roles/investigation
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.org/dc/terms/description
#     http://purl.org/dc/terms/license
#     http://purl.org/dc/terms/title
#     http://www.geneontology.org/formats/oboInOwl#auto-generated-by
#     https://credit.niso.org/contributor-roles/conceptualization
#
# File: eccode.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/eccode.owl
#   Own terms: 0
#   External terms: 249359
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 8743
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0100001
#     http://purl.obolibrary.org/obo/RO_0002327
#     http://purl.obolibrary.org/obo/RO_0002351
#     http://purl.obolibrary.org/obo/eccode.owl
#     http://www.geneontology.org/formats/oboInOwl#hasExactSynonym
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/GO_0000010
#     http://purl.obolibrary.org/obo/GO_0000016
#     http://purl.obolibrary.org/obo/GO_0000034
#     http://purl.obolibrary.org/obo/GO_0000048
#     http://purl.obolibrary.org/obo/GO_0000121
#
# File: foodon.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/foodon.owl
#   Own terms: 28805
#   External terms: 10966
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 10934
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/AGRO_00000025
#     http://purl.obolibrary.org/obo/AGRO_00000322
#     http://purl.obolibrary.org/obo/AGRO_00000360
#     http://purl.obolibrary.org/obo/AGRO_00000363
#     http://purl.obolibrary.org/obo/AGRO_00002071
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/FOODON_00000000
#     http://purl.obolibrary.org/obo/FOODON_00000015
#     http://purl.obolibrary.org/obo/FOODON_00000070
#     http://purl.obolibrary.org/obo/FOODON_00000071
#     http://purl.obolibrary.org/obo/FOODON_00000072
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/AGRO_00000025
#     http://purl.obolibrary.org/obo/AGRO_00000322
#     http://purl.obolibrary.org/obo/AGRO_00000360
#     http://purl.obolibrary.org/obo/AGRO_00000363
#     http://purl.obolibrary.org/obo/AGRO_00002071
#
# File: gtdb.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/gtdb/gtdb.ofn
#   Own terms: 0
#   External terms: 146394
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 146389
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000700
#     http://purl.obolibrary.org/obo/TAXRANK_0000001
#     http://purl.obolibrary.org/obo/TAXRANK_0000002
#     http://purl.obolibrary.org/obo/TAXRANK_0000003
#     http://purl.obolibrary.org/obo/TAXRANK_0000004
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000700
#     http://purl.obolibrary.org/obo/TAXRANK_0000001
#     http://purl.obolibrary.org/obo/TAXRANK_0000002
#     http://purl.obolibrary.org/obo/TAXRANK_0000003
#     http://purl.obolibrary.org/obo/TAXRANK_0000004
#
# File: iao.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/iao.owl
#   Own terms: 283
#   External terms: 130
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 101
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000008
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000032
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000033
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000522
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000524
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/IAO_0000001
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000003
#     http://purl.obolibrary.org/obo/IAO_0000004
#     http://purl.obolibrary.org/obo/IAO_0000005
#   First 5 external terms:
#     http://protege.stanford.edu/plugins/owl/protege#defaultLanguage
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000008
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000032
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000033
#     http://purl.obolibrary.org/obo/APOLLO_SV_00000522
#
# File: interpro.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/interpro/interpro.ofn
#   Own terms: 0
#   External terms: 52757
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 47053
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IPR_IPR000001
#     http://purl.obolibrary.org/obo/IPR_IPR000003
#     http://purl.obolibrary.org/obo/IPR_IPR000006
#     http://purl.obolibrary.org/obo/IPR_IPR000007
#     http://purl.obolibrary.org/obo/IPR_IPR000008
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/GO_0000001
#     http://purl.obolibrary.org/obo/GO_0000002
#     http://purl.obolibrary.org/obo/GO_0000009
#     http://purl.obolibrary.org/obo/GO_0000011
#     http://purl.obolibrary.org/obo/GO_0000012
#
# File: omo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/omo.owl
#   Own terms: 18
#   External terms: 107
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 84
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000027
#     http://purl.obolibrary.org/obo/IAO_0000030
#     http://purl.obolibrary.org/obo/IAO_0000078
#     http://purl.obolibrary.org/obo/IAO_0000102
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/OMO_0001000
#     http://purl.obolibrary.org/obo/OMO_0001001
#     http://purl.obolibrary.org/obo/OMO_0001002
#     http://purl.obolibrary.org/obo/OMO_0002000
#     http://purl.obolibrary.org/obo/OMO_0003000
#   First 5 external terms:
#     http://protege.stanford.edu/plugins/owl/protege#defaultLanguage
#     http://purl.obolibrary.org/obo/IAO_0000002
#     http://purl.obolibrary.org/obo/IAO_0000027
#     http://purl.obolibrary.org/obo/IAO_0000030
#     http://purl.obolibrary.org/obo/IAO_0000078
#
# File: pfam.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/pfam/pfam.ofn
#   Own terms: 0
#   External terms: 24850
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 24077
#   First 5 external terms that are subject of triples:
#     https://w3id.org/biopragmatics/resources/pfam/pfam.ofn
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF00001
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF00002
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF00003
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF00004
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.org/dc/terms/description
#     http://purl.org/dc/terms/license
#     http://purl.org/dc/terms/title
#     http://www.geneontology.org/formats/oboInOwl#auto-generated-by
#     https://w3id.org/biopragmatics/resources/pfam/pfam.ofn
#
# File: po.owl
#   Has imports: Yes
#   Ontology IRI: http://purl.obolibrary.org/obo/po.owl
#   Own terms: 1996
#   External terms: 67
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 50
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/IAO_0000115
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/PO_0000001
#     http://purl.obolibrary.org/obo/PO_0000002
#     http://purl.obolibrary.org/obo/PO_0000003
#     http://purl.obolibrary.org/obo/PO_0000004
#     http://purl.obolibrary.org/obo/PO_0000005
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/IAO_0000115
#
# File: rhea.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/rhea/rhea.ofn
#   Own terms: 0
#   External terms: 324997
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 68535
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/RO#reactionEnabledByMolecularFunction
#     http://purl.obolibrary.org/obo/RO_0000056
#     http://purl.obolibrary.org/obo/RO_0000057
#     http://purl.obolibrary.org/obo/RO_0002233
#     http://purl.obolibrary.org/obo/RO_0002234
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/CHEBI_100
#     http://purl.obolibrary.org/obo/CHEBI_10015
#     http://purl.obolibrary.org/obo/CHEBI_10023
#     http://purl.obolibrary.org/obo/CHEBI_10036
#     http://purl.obolibrary.org/obo/CHEBI_10106
#
# File: ror.owl
#   Has imports: No
#   Ontology IRI: https://w3id.org/biopragmatics/resources/ror/ror.ofn
#   Own terms: 0
#   External terms: 122648
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 122639
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/ENVO_00000856
#   First 5 own terms:
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BFO_0000050
#     http://purl.obolibrary.org/obo/BFO_0000051
#     http://purl.obolibrary.org/obo/BFO_0000062
#     http://purl.obolibrary.org/obo/BFO_0000063
#     http://purl.obolibrary.org/obo/ENVO_00000856
#
# File: so.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/so.owl
#   Own terms: 2639
#   External terms: 190
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 181
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/BS_00003
#     http://purl.obolibrary.org/obo/BS_0000338
#     http://purl.obolibrary.org/obo/BS_0000339
#     http://purl.obolibrary.org/obo/BS_0000340
#     http://purl.obolibrary.org/obo/BS_0000341
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/SO_0000000
#     http://purl.obolibrary.org/obo/SO_0000001
#     http://purl.obolibrary.org/obo/SO_0000002
#     http://purl.obolibrary.org/obo/SO_0000003
#     http://purl.obolibrary.org/obo/SO_0000004
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/BS_00003
#     http://purl.obolibrary.org/obo/BS_0000338
#     http://purl.obolibrary.org/obo/BS_0000339
#     http://purl.obolibrary.org/obo/BS_0000340
#     http://purl.obolibrary.org/obo/BS_0000341
#
# File: taxrank.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/taxrank.owl
#   Own terms: 74
#   External terms: 15
#   Classification: Non-Base. No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 10
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000700
#     http://purl.obolibrary.org/obo/taxrank.owl
#     http://www.geneontology.org/formats/oboInOwl#created_by
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/TAXRANK_0000000
#     http://purl.obolibrary.org/obo/TAXRANK_0000001
#     http://purl.obolibrary.org/obo/TAXRANK_0000002
#     http://purl.obolibrary.org/obo/TAXRANK_0000003
#     http://purl.obolibrary.org/obo/TAXRANK_0000004
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/IAO_0000112
#     http://purl.obolibrary.org/obo/IAO_0000115
#     http://purl.obolibrary.org/obo/IAO_0000700
#     http://purl.obolibrary.org/obo/taxrank.owl
#     http://purl.org/dc/terms/contributor
#
# File: uo.owl
#   Has imports: No
#   Ontology IRI: http://purl.obolibrary.org/obo/uo.owl
#   Own terms: 572
#   External terms: 5
#   Classification: Potential Base (missing -base hint in .owl file name). No -base version available in OBO Foundry
#   External Terms Subject of Triples? Yes
#   Number of external terms that are subjects of triples: 1
#   First 5 external terms that are subject of triples:
#     http://purl.obolibrary.org/obo/uo.owl
#   First 5 own terms:
#     http://purl.obolibrary.org/obo/UO_0000000
#     http://purl.obolibrary.org/obo/UO_0000001
#     http://purl.obolibrary.org/obo/UO_0000002
#     http://purl.obolibrary.org/obo/UO_0000003
#     http://purl.obolibrary.org/obo/UO_0000004
#   First 5 external terms:
#     http://purl.obolibrary.org/obo/has_prefix
#     http://purl.obolibrary.org/obo/is_unit_of
#     http://purl.obolibrary.org/obo/uo.owl
#     http://www.geneontology.org/formats/oboInOwl#hasExactSynonym
#     http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym
#
# Analysis complete!
# CPU times: user 1min, sys: 5.74 s, total: 1min 6s
# Wall time: 2min 4s

# %% [markdown]
# #### Recreate pseudo base versions

# %%
# %%time
import sys
import os
# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
# Import and run the pseudo base creation
from create_pseudo_base_ontology import create_pseudo_base_ontologies
# Run the creation
create_pseudo_base_ontologies(repo_path)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Processing po.owl...
# Using base IRI: http://purl.obolibrary.org/obo/PO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/po.owl --base-iri http://purl.obolibrary.org/obo/PO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
# Created base version for po.owl: po-base.owl
# Processing iao.owl...
# Using base IRI: http://purl.obolibrary.org/obo/IAO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/iao.owl --base-iri http://purl.obolibrary.org/obo/IAO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
# Created base version for iao.owl: iao-base.owl
# Processing omo.owl...
# Using base IRI: http://purl.obolibrary.org/obo/OMO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/omo.owl --base-iri http://purl.obolibrary.org/obo/OMO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
# Created base version for omo.owl: omo-base.owl
# Processing bfo.owl...
# Using base IRI: http://purl.obolibrary.org/obo/BFO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/bfo.owl --base-iri http://purl.obolibrary.org/obo/BFO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
# Created base version for bfo.owl: bfo-base.owl
# Processing foodon.owl...
# Using base IRI: http://purl.obolibrary.org/obo/FOODON_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/foodon.owl --base-iri http://purl.obolibrary.org/obo/FOODON_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
# Created base version for foodon.owl: foodon-base.owl
# Processing uo.owl...
# Using base IRI: http://purl.obolibrary.org/obo/UO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/uo.owl --base-iri http://purl.obolibrary.org/obo/UO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
# Created base version for uo.owl: uo-base.owl
# Processing taxrank.owl...
# Using base IRI: http://purl.obolibrary.org/obo/TAXRANK_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/taxrank.owl --base-iri http://purl.obolibrary.org/obo/TAXRANK_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl
# Created base version for taxrank.owl: taxrank-base.owl
# Processing so.owl...
# Using base IRI: http://purl.obolibrary.org/obo/SO_
# Executing command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/non-base-ontologies/so.owl --base-iri http://purl.obolibrary.org/obo/SO_ --axioms external --preserve-structure false --trim false remove --select imports --trim false --output /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl
# Created base version for so.owl: so-base.owl
# Copying PyOBO ontology to main directory: gtdb.owl
# Copying PyOBO ontology to main directory: pfam.owl
# Copying PyOBO ontology to main directory: eccode.owl
# Copying PyOBO ontology to main directory: credit.owl
# Copying PyOBO ontology to main directory: rhea.owl
# Copying PyOBO ontology to main directory: interpro.owl
# Copying PyOBO ontology to main directory: ror.owl
#
# Processing complete!
# CPU times: user 34.6 ms, sys: 834 ms, total: 868 ms
# Wall time: 44.9 s
# True

# %% [markdown]
# #### Analyze the prefixes

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import the prefix analyzer
from analyze_prefixes import analyze_all_ontologies, generate_prefix_mapping

# Define input directory path
input_dir = os.path.join(repo_path, 'ontology_data_owl_core')

# Run the analysis
print(f"Analyzing ontologies in: {input_dir}")
results = analyze_all_ontologies(input_dir)

# Generate and save prefix mapping
mapping_content = generate_prefix_mapping(results)
mapping_file = os.path.join(repo_path, 'prefix_mapping.txt')

with open(mapping_file, 'w') as f:
    f.write(mapping_content)

print(f"\nPrefix mapping file generated at: {mapping_file}")

# Print summary of analysis
print("\nSummary of analysis:")
for filename, data in results.items():
    print(f"\n{filename}:")
    print(f"  Declared prefixes: {len(data['prefixes'])}")
    additional_prefixes = set(data['prefix_to_iris'].keys()) - data['prefixes']
    print(f"  Potential additional prefixes needed: {len(additional_prefixes)}")
    if additional_prefixes:
        print("  Additional prefixes:")
        for prefix in sorted(additional_prefixes):
            iris = data['prefix_to_iris'][prefix]
            if iris:
                print(f"    - {prefix}: {next(iter(iris))}")
# Out:
# Analyzing ontologies in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_core
#
# Analyzing ncbitaxon.owl...
# KeyboardInterrupt

# %% [markdown]
# #### Merge Ontologies

# %%
# %%time
import sys
import os
import subprocess
from threading import Thread
import time
from pathlib import Path
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(
    filename='merge_memory.log',
    level=logging.INFO,
    format='%(asctime)s - %(message)s'
)

# Initialize peak memory tracking
peak_memory_gb = 0
last_logged_memory = 0

def parse_memory_output(mem_line):
    parts = mem_line.split()
    used_mem = parts[2]
    value = float(used_mem[:-2])
    return value * 1024 if used_mem.endswith('Ti') else value

def monitor_memory():
    global peak_memory_gb, last_logged_memory
    while True:
        try:
            mem_info = subprocess.check_output(['free', '-h']).decode('utf-8').split('\n')
            current_memory_gb = parse_memory_output(mem_info[1])
            peak_memory_gb = max(peak_memory_gb, current_memory_gb)
            
            # Log if memory changed by more than 10GB
            if abs(current_memory_gb - last_logged_memory) > 10:
                logging.info(f"Memory: {current_memory_gb:.0f}GB (Peak: {peak_memory_gb:.0f}GB)")
                last_logged_memory = current_memory_gb
            
            time.sleep(60)
        except:
            break

# Start memory monitoring in background
monitor_thread = Thread(target=monitor_memory, daemon=True)
monitor_thread.start()

# Run merge
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
from merge_ontologies import merge_ontologies

print("Starting ontology merge - Check merge_memory.log for memory usage details")
logging.info("Starting ontology merge")

merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',
    output_filename='ontology_data_owl.owl'
)

# Log final statistics
logging.info(f"Merge completed - Final peak memory: {peak_memory_gb:.0f}GB")
print(f"\nMerge completed - Peak memory usage: {peak_memory_gb:.0f}GB")
# Out:
# Starting ontology merge - Check merge_memory.log for memory usage details
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl
# Found 30 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.owl
#
# Merge completed - Peak memory usage: 1331GB
# CPU times: user 497 ms, sys: 369 ms, total: 866 ms
# Wall time: 1h 26min 3s

# %%
# %%time
import sys
import os
import subprocess
from threading import Thread
import time
from pathlib import Path
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(
    filename='merge_memory.log',
    level=logging.INFO,
    format='%(asctime)s - %(message)s'
)

# Initialize peak memory tracking
peak_memory_gb = 0
last_logged_memory = 0

def parse_memory_output(mem_line):
    parts = mem_line.split()
    used_mem = parts[2]
    value = float(used_mem[:-2])
    return value * 1024 if used_mem.endswith('Ti') else value

def monitor_memory():
    global peak_memory_gb, last_logged_memory
    while True:
        try:
            mem_info = subprocess.check_output(['free', '-h']).decode('utf-8').split('\n')
            current_memory_gb = parse_memory_output(mem_info[1])
            peak_memory_gb = max(peak_memory_gb, current_memory_gb)
            
            # Log if memory changed by more than 10GB
            if abs(current_memory_gb - last_logged_memory) > 10:
                logging.info(f"Memory: {current_memory_gb:.0f}GB (Peak: {peak_memory_gb:.0f}GB)")
                last_logged_memory = current_memory_gb
            
            time.sleep(60)
        except:
            break

# Start memory monitoring in background
monitor_thread = Thread(target=monitor_memory, daemon=True)
monitor_thread.start()

# Run merge
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
from merge_ontologies_v2 import merge_ontologies

print("Starting ontology merge - Check merge_memory.log for memory usage details")
logging.info("Starting ontology merge")

merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',
    output_filename='ontology_data_owl_prefix_EC_UP.owl'
)

# Log final statistics
logging.info(f"Merge completed - Final peak memory: {peak_memory_gb:.0f}GB")
print(f"\nMerge completed - Peak memory usage: {peak_memory_gb:.0f}GB")
# Out:
# Starting ontology merge - Check merge_memory.log for memory usage details
# Found 30 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
#
# Executing initial merge command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/merged_intermediate.owl
#
# Executing annotate command:
# robot annotate --input /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/merged_intermediate.owl --annotation-file /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/prefix_mapping.txt --prefix EC: http://purl.obolibrary.org/obo/EC_ --prefix eccode: http://purl.obolibrary.org/obo/EC_ --prefix UP: http://purl.uniprot.org/uniprot/ --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/prefix_fixed.owl
#
# Executing remove command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/prefix_fixed.owl --term oio:id --select annotation-properties --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_prefix_EC_UP.owl
#
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_prefix_EC_UP.owl
#
# Merge completed - Peak memory usage: 1331GB
# CPU times: user 983 ms, sys: 630 ms, total: 1.61 s
# Wall time: 3h 44min 30s

# %%
# %%time
import sys
import os
import subprocess
from threading import Thread
import time
from pathlib import Path
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(
    filename='merge_memory.log',
    level=logging.INFO,
    format='%(asctime)s - %(message)s'
)

# Initialize peak memory tracking
peak_memory_gb = 0
last_logged_memory = 0

def parse_memory_output(mem_line):
    parts = mem_line.split()
    used_mem = parts[2]
    value = float(used_mem[:-2])
    return value * 1024 if used_mem.endswith('Ti') else value

def monitor_memory():
    global peak_memory_gb, last_logged_memory
    while True:
        try:
            mem_info = subprocess.check_output(['free', '-h']).decode('utf-8').split('\n')
            current_memory_gb = parse_memory_output(mem_info[1])
            peak_memory_gb = max(peak_memory_gb, current_memory_gb)
            
            # Log if memory changed by more than 10GB
            if abs(current_memory_gb - last_logged_memory) > 10:
                logging.info(f"Memory: {current_memory_gb:.0f}GB (Peak: {peak_memory_gb:.0f}GB)")
                last_logged_memory = current_memory_gb
            
            time.sleep(60)
        except:
            break

# Start memory monitoring in background
monitor_thread = Thread(target=monitor_memory, daemon=True)
monitor_thread.start()

# Run merge
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
from merge_ontologies_v3 import merge_ontologies

print("Starting ontology merge - Check merge_memory.log for memory usage details")
logging.info("Starting ontology merge")

merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',
    output_filename='ontology_data_owl_set_prefixes.owl'
)

# Log final statistics
logging.info(f"Merge completed - Final peak memory: {peak_memory_gb:.0f}GB")
print(f"\nMerge completed - Peak memory usage: {peak_memory_gb:.0f}GB")
# Out:
# Starting ontology merge - Check merge_memory.log for memory usage details
# Found 30 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
#
# Executing initial merge command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/merged_intermediate.owl
# KeyboardInterrupt

# %%
# %%time
import sys
import os
import subprocess

repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
output_dir = os.path.join(repo_path, 'outputs')
intermediate_dir = os.path.join(output_dir, 'intermediary_ontology')

# Input file (your existing prefix_fixed.owl)
intermediate_file2 = os.path.join(intermediate_dir, 'prefix_fixed.owl')

# Output file
output_file = os.path.join(output_dir, 'ontology_data_owl_set_prefixes.owl')

# Step 3: Remove annotations using filter
filter_command = [
    'robot', 'remove',
    '--input', intermediate_file2,
    '--term', 'oio:id',
    '--select', 'annotation-properties',
    '--output', output_file
]

print("\nExecuting remove command:")
print(f"{' '.join(filter_command)}")

try:
    subprocess.run(filter_command, check=True, capture_output=True, text=True)
    print(f"\nSuccessfully created final ontology at {output_file}")
except subprocess.CalledProcessError as e:
    print(f"\nError executing ROBOT command:")
    print(f"Return code: {e.returncode}")
    if e.stdout:
        print("STDOUT:", e.stdout)
    if e.stderr:
        print("STDERR:", e.stderr)
# Out:
# Executing remove command:
# robot remove --input /scratch/jplfaria/KBase_CDM_Ontologies/outputs/intermediary_ontology/prefix_fixed.owl --term oio:id --select annotation-properties --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_set_prefixes.owl
#
# Successfully created final ontology at /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_set_prefixes.owl
# CPU times: user 222 ms, sys: 191 ms, total: 414 ms
# Wall time: 1h 7min 21s

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the merge
from merge_ontologies_v4 import merge_ontologies

# Run the merge
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl_test',  # Your input directory
    output_filename='test_merged_ontologies.owl'  # Your output filename
)

# %%
import os
from rdflib import Graph
import csv
from typing import Dict, Tuple

def extract_prefixes_from_ontology(file_path: str) -> dict:
    """Extract prefixes from a single ontology file."""
    g = Graph()
    g.parse(file_path, format="xml" if file_path.endswith(".owl") else "turtle")
    return {prefix: str(namespace) for prefix, namespace in g.namespaces()}

def extract_prefixes_from_directory(directory: str) -> Tuple[Dict[str, Dict[str, str]], Dict[str, str]]:
    """
    Extract prefixes from all ontology files in a directory and track per-file prefixes.
    
    Returns:
        Tuple containing:
        - Dictionary mapping filenames to their prefix dictionaries
        - Combined dictionary of all prefixes
    """
    per_file_prefixes = {}
    all_prefixes = {}
    
    for filename in os.listdir(directory):
        if filename.endswith((".owl", ".ttl", ".ofn", ".rdf")):
            file_path = os.path.join(directory, filename)
            print(f"Processing {file_path}...")
            try:
                file_prefixes = extract_prefixes_from_ontology(file_path)
                per_file_prefixes[filename] = file_prefixes
                all_prefixes.update(file_prefixes)
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
    
    return per_file_prefixes, all_prefixes

def save_prefixes_to_csv(prefixes: dict, output_file: str, include_source: bool = False):
    """Save prefixes to a CSV file."""
    with open(output_file, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        if include_source:
            writer.writerow(["Source", "Prefix", "Namespace"])
            for source, prefix_dict in prefixes.items():
                for prefix, namespace in sorted(prefix_dict.items()):
                    writer.writerow([source, prefix, namespace])
        else:
            writer.writerow(["Prefix", "Namespace"])
            for prefix, namespace in sorted(prefixes.items()):
                writer.writerow([prefix, namespace])

def analyze_prefixes(input_dir: str, merged_file: str, output_dir: str):
    """
    Analyze prefixes in both individual ontologies and merged ontology.
    
    Args:
        input_dir: Directory containing individual ontologies
        merged_file: Path to the merged ontology file
        output_dir: Directory for output files
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Analyze individual ontologies
    print("\nAnalyzing individual ontologies...")
    per_file_prefixes, all_prefixes = extract_prefixes_from_directory(input_dir)
    
    # Save individual ontology prefixes
    individual_output = os.path.join(output_dir, "individual_prefixes.csv")
    save_prefixes_to_csv(per_file_prefixes, individual_output, include_source=True)
    print(f"Individual ontology prefixes saved to {individual_output}")
    
    # Save combined prefixes from all individual ontologies
    combined_output = os.path.join(output_dir, "combined_prefixes.csv")
    save_prefixes_to_csv(all_prefixes, combined_output)
    print(f"Combined prefixes saved to {combined_output}")
    
    # Analyze merged ontology
    if os.path.exists(merged_file):
        print("\nAnalyzing merged ontology...")
        try:
            merged_prefixes = extract_prefixes_from_ontology(merged_file)
            merged_output = os.path.join(output_dir, "merged_prefixes.csv")
            save_prefixes_to_csv(merged_prefixes, merged_output)
            print(f"Merged ontology prefixes saved to {merged_output}")
            
            # Compare prefixes
            print("\nPrefix Analysis:")
            original_prefixes = set(all_prefixes.keys())
            merged_prefix_set = set(merged_prefixes.keys())
            
            print(f"\nTotal prefixes in individual ontologies: {len(original_prefixes)}")
            print(f"Total prefixes in merged ontology: {len(merged_prefix_set)}")
            
            lost_prefixes = original_prefixes - merged_prefix_set
            new_prefixes = merged_prefix_set - original_prefixes
            
            if lost_prefixes:
                print(f"\nPrefixes lost after merging ({len(lost_prefixes)}):")
                for prefix in sorted(lost_prefixes):
                    print(f"  - {prefix}: {all_prefixes[prefix]}")
            
            if new_prefixes:
                print(f"\nNew prefixes in merged ontology ({len(new_prefixes)}):")
                for prefix in sorted(new_prefixes):
                    print(f"  - {prefix}: {merged_prefixes[prefix]}")
                    
        except Exception as e:
            print(f"Error analyzing merged ontology: {e}")
    else:
        print(f"\nMerged ontology file not found: {merged_file}")

if __name__ == "__main__":
    # Configuration
    input_dir = "/scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl"
    merged_file = "/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.owl"
    output_dir = "/scratch/jplfaria/KBase_CDM_Ontologies/outputs/prefix_analysis"
    
    analyze_prefixes(input_dir, merged_file, output_dir)
# Out:
# Analyzing individual ontologies...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl...
# Processing /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl...
# Individual ontology prefixes saved to /scratch/jplfaria/KBase_CDM_Ontologies/outputs/prefix_analysis/individual_prefixes.csv
# Combined prefixes saved to /scratch/jplfaria/KBase_CDM_Ontologies/outputs/prefix_analysis/combined_prefixes.csv
#
# Analyzing merged ontology...
# Merged ontology prefixes saved to /scratch/jplfaria/KBase_CDM_Ontologies/outputs/prefix_analysis/merged_prefixes.csv
#
# Prefix Analysis:
#
# Total prefixes in individual ontologies: 109
# Total prefixes in merged ontology: 59
#
# Prefixes lost after merging (54):
#   - BFO: http://purl.obolibrary.org/obo/BFO_
#   - CHEBI: http://purl.obolibrary.org/obo/CHEBI_
#   - ENVO: http://purl.obolibrary.org/obo/ENVO_
#   - GO: http://purl.obolibrary.org/obo/GO_
#   - IAO: http://purl.obolibrary.org/obo/IAO_
#   - NCBITaxon: http://purl.obolibrary.org/obo/NCBITaxon_
#   - OBI: http://purl.obolibrary.org/obo/OBI_
#   - OMO: http://purl.obolibrary.org/obo/OMO_
#   - RO: http://purl.obolibrary.org/obo/RO_
#   - TAXRANK: http://purl.obolibrary.org/obo/TAXRANK_
#   - asfis: https://www.fao.org/fishery/en/aqspecies/
#   - biolink: https://w3id.org/biolink/vocab/
#   - chebi1: http://purl.obolibrary.org/obo/chebi#2
#   - chebi2: http://purl.obolibrary.org/obo/chebi#
#   - cnrs: https://bioregistry.io/cnrs:
#   - credit: https://credit.niso.org/contributor-roles/
#   - debio: https://biopragmatics.github.io/debio/
#   - eccode: https://www.ebi.ac.uk/intenz/query?cmd=SearchEC&ec=
#   - ecocyc: https://ecocyc.org/gene?id=
#   - efo: http://www.ebi.ac.uk/efo/
#   - eolife: http://eol.org/pages/
#   - funderregistry: http://data.crossref.org/fundingdata/funder/
#   - geonames: https://www.geonames.org/
#   - grid: https://www.grid.ac/institutes/
#   - grin: http://www.ars-grin.gov/cgi-bin/npgs/html/taxon.pl?
#   - gtdb: https://gtdb.ecogenomic.org/tree?r=
#   - hesa: https://bioregistry.io/hesa:
#   - indexfungorum: http://www.indexfungorum.org/names/NamesRecord.asp?RecordID=
#   - interpro: https://www.ebi.ac.uk/interpro/entry/InterPro/
#   - isni: http://www.isni.org/isni/
#   - itis: http://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=
#   - kegg.reaction: https://www.kegg.jp/entry/
#   - langual: http://www.langual.org/langual_thesaurus.asp?termid=
#   - macie: https://www.ebi.ac.uk/thornton-srv/m-csa/search/?s=
#   - metacyc.compound: https://metacyc.org/compound?orgid=META&id=
#   - obo1: http://www.geneontology.org/formats/oboInOwl#http://purl.obolibrary.org/obo/
#   - orcid: https://orcid.org/
#   - pfam: https://www.ebi.ac.uk/interpro/entry/pfam/
#   - pfam.clan: https://www.ebi.ac.uk/interpro/set/pfam/
#   - po: http://purl.obolibrary.org/obo/po#
#   - pr: http://purl.obolibrary.org/obo/pr#
#   - reactome: https://reactome.org/content/detail/
#   - rhea1: http://purl.obolibrary.org/obo/rhea#
#   - ror: https://ror.org/
#   - siren: https://bioregistry.io/reference/siren:
#   - so: http://purl.obolibrary.org/obo/so#
#   - subsets: http://purl.obolibrary.org/obo/ro/subsets#
#   - uberon: http://purl.obolibrary.org/obo/uberon#
#   - ubprop: http://purl.obolibrary.org/obo/ubprop#
#   - ucas: https://bioregistry.io/ucas:
#   - ukprn: https://bioregistry.io/ukprn:
#   - uniprot: http://purl.uniprot.org/uniprot/
#   - wikidata: http://www.wikidata.org/entity/
#   - wikipedia: https://en.wikipedia.org/wiki/
#
# New prefixes in merged ontology (4):
#   - chebi5: http://purl.obolibrary.org/obo/chebi#3
#   - chebi6: http://purl.obolibrary.org/obo/chebi#1
#   - obo2: http://www.geneontology.org/formats/oboInOwl#http://purl.obolibrary.org/obo/
#   - vocab: https://w3id.org/biolink/vocab/

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the merge
from merge_ontologies import merge_ontologies

# Run the merge with custom input directory and output filename
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl_core',  # Custom input directory
    output_filename='ontology_data_owl_core.owl'    # Custom output filename
)
# Out:
# Using ROBOT at: /cdm_shared_workspace/user_shared_workspace/Jose/install_stuff/robot/robot
# Looking for ontology files in: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core
# Found 4 ontology files:
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/ncbitaxon.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/envo.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/chebi.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/go.owl
# Created list of merged ontologies at: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/ncbitaxon.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/envo.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/chebi.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core/go.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core.owl
#
# ROBOT Output:
# Successfully merged ontologies into /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core.owl
# CPU times: user 1.28 s, sys: 547 ms, total: 1.83 s
# Wall time: 35min 27s
# True

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import the merge function
from merge_ontologies_custom_order import merge_ontologies

# Define the desired order for merging (filenames must be present in the input directory)
desired_order = [
    'ncbitaxon.owl',
    'go.owl',
    'envo.owl',
    'chebi.owl',
    'bfo-base.owl',
    'caro-base.owl',
    'cl-base.owl',
    'fao-base.owl',
    'foodon-base.owl',
    'iao-base.owl',
    'obi-base.owl',
    'omo-base.owl',
    'pato-base.owl',
    'pco-base.owl',
    'po-base.owl',
    'ro-base.owl',
    'so-base.owl',
    'taxrank-base.owl',
    'uberon-base.owl',
    'uo-base.owl',
    'gtdb.owl',
    'eccode.owl',
    'pfam.owl',
    'rhea.owl',
    'credit.owl',
    'ror.owl',
    'interpro.owl',
    'seed.owl',
    'modelseed.owl',
    'kegg.owl',
    'metacyc.owl'
]

# Run the merge with custom input directory, output filename, and the specified file order
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',  # Custom input directory
    output_filename='ontology_data_owl_31.owl',  # Custom output filename
    ontology_order=desired_order
)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl
# Found 31 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/seed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/bfo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/caro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/cl-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/fao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/foodon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/iao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/obi-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/omo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pato-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pco-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/po-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/so-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/taxrank-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uberon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/uo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/pfam.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/credit.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ror.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/interpro.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/seed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31.owl
# CPU times: user 706 ms, sys: 216 ms, total: 922 ms
# Wall time: 1h 12min 20s
# True

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import the merge function
from merge_ontologies_custom_order import merge_ontologies

# Define the desired order for merging (filenames must be present in the input directory)
desired_order = [
    'go.owl',
    'chebi.owl',
    'eccode.owl',
    'rhea.owl',
    'modelseed.owl',
    'kegg.owl',
    'metacyc.owl'
]

# Run the merge with custom input directory, output filename, and the specified file order
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',  # Custom input directory
    output_filename='7_biochemistry.owl',  # Custom output filename
    ontology_order=desired_order
)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl
# Found 7 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/7_biochemistry.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/kegg.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/metacyc.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/7_biochemistry.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/7_biochemistry.owl
# CPU times: user 86 ms, sys: 48 ms, total: 134 ms
# Wall time: 11min 55s
# True

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import the merge function
from merge_ontologies_custom_order import merge_ontologies

# Define the desired order for merging (filenames must be present in the input directory)
desired_order = [
    'ncbitaxon.owl',
    'go.owl',
    'envo.owl',
    'chebi.owl',
    'gtdb.owl',
    'rhea.owl',
    'eccode.owl',
    'modelseed.owl'
]

# Run the merge with custom input directory, output filename, and the specified file order
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',  # Custom input directory
    output_filename='core_plus_ec_rhea_gtdb_modelseed.owl',  # Custom output filename
    ontology_order=desired_order
)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl
# Found 8 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/core_plus_ec_rhea_gtdb_modelseed.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/envo.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/chebi.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/gtdb.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/rhea.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/eccode.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/modelseed.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/core_plus_ec_rhea_gtdb_modelseed.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/core_plus_ec_rhea_gtdb_modelseed.owl
# CPU times: user 320 ms, sys: 255 ms, total: 574 ms
# Wall time: 58min 57s
# True

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import the merge function
from merge_ontologies_custom_order import merge_ontologies

# Define the desired order for merging (filenames must be present in the input directory)
desired_order = [
    'ncbitaxon.owl',
    'go.owl'
]

# Run the merge with custom input directory, output filename, and the specified file order
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',  # Custom input directory
    output_filename='ncbi_go.owl',  # Custom output filename
    ontology_order=desired_order
)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl
# Found 2 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ncbi_go.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/ncbitaxon.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl/go.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ncbi_go.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ncbi_go.owl
# CPU times: user 309 ms, sys: 168 ms, total: 478 ms
# Wall time: 50min 36s
# True

# %%
# %%time
import sys
import os
import subprocess
from threading import Thread
import time
from pathlib import Path
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(
    filename='merge_memory.log',
    level=logging.INFO,
    format='%(asctime)s - %(message)s'
)

# Initialize peak memory tracking
peak_memory_gb = 0
last_logged_memory = 0

def parse_memory_output(mem_line):
    parts = mem_line.split()
    used_mem = parts[2]
    value = float(used_mem[:-2])
    return value * 1024 if used_mem.endswith('Ti') else value

def monitor_memory():
    global peak_memory_gb, last_logged_memory
    while True:
        try:
            mem_info = subprocess.check_output(['free', '-h']).decode('utf-8').split('\n')
            current_memory_gb = parse_memory_output(mem_info[1])
            peak_memory_gb = max(peak_memory_gb, current_memory_gb)
            
            # Log if memory changed by more than 10GB
            if abs(current_memory_gb - last_logged_memory) > 10:
                logging.info(f"Memory: {current_memory_gb:.0f}GB (Peak: {peak_memory_gb:.0f}GB)")
                last_logged_memory = current_memory_gb
            
            time.sleep(60)
        except:
            break

# Start memory monitoring in background
monitor_thread = Thread(target=monitor_memory, daemon=True)
monitor_thread.start()

# Run merge
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)
from merge_ontologies_v2 import merge_ontologies

print("Starting ontology merge - Check merge_memory.log for memory usage details")
logging.info("Starting ontology merge")

merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl',
    output_filename='ontology_data_owl_no_eccode.owl'
)

# Log final statistics
logging.info(f"Merge completed - Final peak memory: {peak_memory_gb:.0f}GB")
print(f"\nMerge completed - Peak memory usage: {peak_memory_gb:.0f}GB")

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the merge
from merge_ontologies import merge_ontologies

# Run the merge with custom input directory and output filename
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl_core_ec',  # Custom input directory
    output_filename='ontology_data_owl_core_ec.owl'    # Custom output filename
)
# Out:
# Using ROBOT at: /cdm_shared_workspace/user_shared_workspace/Jose/install_stuff/robot/robot
# Looking for ontology files in: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec
# Found 5 ontology files:
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/ncbitaxon.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/envo.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/chebi.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/eccode.owl
#   - /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/go.owl
# Created list of merged ontologies at: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core_ec.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/ncbitaxon.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/envo.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/chebi.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/eccode.owl --input /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/ontology_data_owl_core_ec/go.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core_ec.owl
#
# ROBOT Output:
# Successfully merged ontologies into /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/ontology_data_owl_core_ec.owl
# CPU times: user 6.49 s, sys: 0 ns, total: 6.49 s
# Wall time: 1h 10min 13s
# True

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the merge
from merge_ontologies import merge_ontologies

# Run the merge with custom input directory and output filename
merge_ontologies(
    repo_path,
    input_dir_name='ontology_data_owl_base',  # Custom input directory
    output_filename='ontology_data_owl_base.owl'    # Custom output filename
)
# Out:
# Using ROBOT at: /scratch/jplfaria/install_stuff/robot/robot
# Looking for ontology files in: /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base
# Found 14 ontology files:
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/foodon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/cl-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/pco-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/iao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/caro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/uberon-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/uo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/omo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/bfo-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/po-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/ro-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/obi-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/fao-base.owl
#   - /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/pato-base.owl
# Created list of merged ontologies at: /scratch/jplfaria/KBase_CDM_Ontologies/ontologies_merged.txt
# Saving output to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_base.owl
#
# Executing command:
# robot merge --annotate-defined-by true --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/foodon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/cl-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/pco-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/iao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/caro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/uberon-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/uo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/omo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/bfo-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/po-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/ro-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/obi-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/fao-base.owl --input /scratch/jplfaria/KBase_CDM_Ontologies/ontology_data_owl_base/pato-base.owl remove --axioms disjoint --trim true --preserve-structure false remove --term owl:Nothing --trim true --preserve-structure false --output /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_base.owl
#
# ROBOT Output:
# Successfully merged ontologies into /scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_base.owl
# CPU times: user 11 ms, sys: 6.37 ms, total: 17.4 ms
# Wall time: 56.8 s
# True

# %% [markdown]
# #### Create Semantic SQL DB

# %%
import sys
print(f"Current Python executable: {sys.executable}")
# Out:
# Current Python executable: /home/jplfaria/miniconda3/bin/python

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the database creation
from create_semantic_sql_db import create_semantic_sql_db

# Run the database creation with custom input filename
create_semantic_sql_db(
    repo_path,
    input_owl_filename='eccode.owl'
)
# Out:
# Error occurred: Could not find semsql installation location
# CPU times: user 24.9 ms, sys: 128 μs, total: 25.1 ms
# Wall time: 398 ms
# Traceback (most recent call last):
#   File "/scratch/jplfaria/KBase_CDM_Ontologies/scripts/create_semantic_sql_db.py", line 24, in create_semantic_sql_db
#     raise Exception("Could not find semsql installation location")
# Exception: Could not find semsql installation location
# False

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the database creation
from create_semantic_sql_db import create_semantic_sql_db

# Run the database creation with custom input filename
create_semantic_sql_db(
    repo_path,
    input_owl_filename='ontology_data_owl.owl'
)
# Out:
# Input OWL file: ontology_data_owl.owl
# Output DB file: ontology_data_owl.db
# Working directory: /scratch/jplfaria/KBase_CDM_Ontologies/outputs
#
# Executing command:
#
#         export PATH="/scratch/jplfaria/bin:$PATH"
#         source /home/jplfaria/scratch/install_stuff/setup_oak_env.sh
#         /home/jplfaria/scratch/install_stuff/semsql/bin/semsql make ontology_data_owl.db
#
#
# Output:
# robot \
# remove -i ontology_data_owl.owl --axioms "equivalent disjoint annotation abox type" \
# filter --exclude-terms /home/jplfaria/scratch/install_stuff/semsql/semsql/builder//exclude-terms.txt \
# -o ontology_data_owl-min.owl
# touch ontology_data_owl-properties.txt
# grep -v ^prefix, /home/jplfaria/scratch/install_stuff/semsql/semsql/builder/prefixes/prefixes.csv | grep -v ^obo, | perl -npe 's@,(.*)@: "$1"@' > ontology_data_owl-prefixes.yaml.tmp && mv ontology_data_owl-prefixes.yaml.tmp ontology_data_owl-prefixes.yaml
# relation-graph --disable-owl-nothing true \
# --ontology-file ontology_data_owl-min.owl \
#  \
# --output-file ontology_data_owl-relation-graph.tsv.tmp \
# --equivalence-as-subclass true \
# --mode TSV \
# --prefixes ontology_data_owl-prefixes.yaml \
# --output-individuals true \
# --output-subclasses true \
# --reflexive-subclasses true && \
# mv ontology_data_owl-relation-graph.tsv.tmp ontology_data_owl-relation-graph.tsv
# rm ontology_data_owl-properties.txt ontology_data_owl-min.owl ontology_data_owl-prefixes.yaml
#
#
# Errors:
# Picked up _JAVA_OPTIONS: -Xmx4000G
# relation-graph is running with Java arguments: -Xmx4000G
# Picked up _JAVA_OPTIONS: -Xmx4000G
# Error: Could not find or load main class org.renci.relationgraph.Main
# Caused by: java.lang.ClassNotFoundException: org.renci.relationgraph.Main
# make: *** [/home/jplfaria/scratch/install_stuff/semsql/semsql/builder/build.Makefile:72: ontology_data_owl-relation-graph.tsv] Error 1
#
# CPU times: user 30.1 ms, sys: 34.9 ms, total: 65 ms
# Wall time: 31min 4s
# False

# %% [markdown]
# #### Extract SQLite tables to .tsv

# %%
# %%time
import sys
import os

# Add the scripts directory to the Python path
repo_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_path = os.path.join(repo_path, 'scripts')
sys.path.append(scripts_path)

# Import and run the extraction
from extract_sql_tables_to_tsv import extract_sql_tables_to_tsv

# Run the extraction
extract_sql_tables_to_tsv(repo_path)
# Out:
# Reading database from: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/CDM_merged_ontologies.db
# Saving TSV files to: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables
# Processing table: term_association
# Exported 'term_association' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/term_association.tsv'
# Processing table: has_oio_synonym_statement
# Exported 'has_oio_synonym_statement' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/has_oio_synonym_statement.tsv'
# Processing table: anonymous_expression
# Exported 'anonymous_expression' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/anonymous_expression.tsv'
# Processing table: anonymous_class_expression
# Exported 'anonymous_class_expression' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/anonymous_class_expression.tsv'
# Processing table: anonymous_property_expression
# Exported 'anonymous_property_expression' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/anonymous_property_expression.tsv'
# Processing table: anonymous_individual_expression
# Exported 'anonymous_individual_expression' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/anonymous_individual_expression.tsv'
# Processing table: owl_restriction
# Exported 'owl_restriction' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/owl_restriction.tsv'
# Processing table: owl_complex_axiom
# Exported 'owl_complex_axiom' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/owl_complex_axiom.tsv'
# Processing table: prefix
# Exported 'prefix' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/prefix.tsv'
# Processing table: rdf_list_statement
# Exported 'rdf_list_statement' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/rdf_list_statement.tsv'
# Processing table: rdf_level_summary_statistic
# Exported 'rdf_level_summary_statistic' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/rdf_level_summary_statistic.tsv'
# Processing table: relation_graph_construct
# Exported 'relation_graph_construct' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/relation_graph_construct.tsv'
# Processing table: subgraph_query
# Exported 'subgraph_query' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/subgraph_query.tsv'
# Processing table: entailed_edge
# Exported 'entailed_edge' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/entailed_edge.tsv'
# Processing table: repair_action
# Exported 'repair_action' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/repair_action.tsv'
# Processing table: problem
# Exported 'problem' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/problem.tsv'
# Processing table: lexical_problem
# Exported 'lexical_problem' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/lexical_problem.tsv'
# Processing table: statements
# Exported 'statements' to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables/statements.tsv'
#
# All tables have been exported to TSV files in: /cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables
# CPU times: user 24min 6s, sys: 4min 6s, total: 28min 13s
# Wall time: 28min 13s
# True

# %%
# %%time
import os
import sqlite3
import pandas as pd
#Specify the output directory
output_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Connect to the SQLite database
conn = sqlite3.connect('/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31.db')

# Get a list of all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Extract each table and save as TSV
for table in tables:
    table_name = table[0]
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    output_path = os.path.join(output_dir, f"{table_name}.tsv")
    df.to_csv(output_path, sep='\t', index=False)
    print(f"Table '{table_name}' has been exported to '{output_path}'")

# Close the connection
conn.close()
print("All tables have been exported to TSV files in the specified directory.")
# Out:
# Table 'prefix' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/prefix.tsv'
# Table 'rdf_list_statement' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/rdf_list_statement.tsv'
# Table 'rdf_level_summary_statistic' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/rdf_level_summary_statistic.tsv'
# Table 'anonymous_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/anonymous_expression.tsv'
# Table 'anonymous_class_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/anonymous_class_expression.tsv'
# Table 'anonymous_property_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/anonymous_property_expression.tsv'
# Table 'anonymous_individual_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/anonymous_individual_expression.tsv'
# Table 'owl_restriction' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/owl_restriction.tsv'
# Table 'owl_complex_axiom' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/owl_complex_axiom.tsv'
# Table 'has_oio_synonym_statement' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/has_oio_synonym_statement.tsv'
# Table 'repair_action' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/repair_action.tsv'
# Table 'problem' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/problem.tsv'
# Table 'lexical_problem' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/lexical_problem.tsv'
# Table 'relation_graph_construct' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/relation_graph_construct.tsv'
# Table 'subgraph_query' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/subgraph_query.tsv'
# Table 'entailed_edge' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/entailed_edge.tsv'
# Table 'term_association' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/term_association.tsv'
# Table 'statements' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl_31/statements.tsv'
# All tables have been exported to TSV files in the specified directory.
# CPU times: user 11min 11s, sys: 1min 24s, total: 12min 36s
# Wall time: 12min 46s

# %%
# %%time
import os
import sqlite3
import pandas as pd

# Specify the output directory
output_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Connect to the SQLite database
conn = sqlite3.connect('/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.db')

# Get a list of all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Extract each table and save as Parquet
for table in tables:
    table_name = table[0]
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    output_path = os.path.join(output_dir, f"{table_name}.parquet")
    df.to_parquet(output_path, index=False)
    print(f"Table '{table_name}' has been exported to '{output_path}'")

# Close the connection
conn.close()

print("All tables have been exported to Parquet files in the specified directory.")
# Out:
# Table 'term_association' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/term_association.parquet'
# Table 'has_oio_synonym_statement' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/has_oio_synonym_statement.parquet'
# Table 'anonymous_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/anonymous_expression.parquet'
# Table 'anonymous_class_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/anonymous_class_expression.parquet'
# Table 'anonymous_property_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/anonymous_property_expression.parquet'
# Table 'anonymous_individual_expression' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/anonymous_individual_expression.parquet'
# Table 'owl_restriction' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/owl_restriction.parquet'
# Table 'owl_complex_axiom' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/owl_complex_axiom.parquet'
# Table 'prefix' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/prefix.parquet'
# Table 'rdf_list_statement' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/rdf_list_statement.parquet'
# Table 'rdf_level_summary_statistic' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/rdf_level_summary_statistic.parquet'
# Table 'relation_graph_construct' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/relation_graph_construct.parquet'
# Table 'subgraph_query' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/subgraph_query.parquet'
# Table 'entailed_edge' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/entailed_edge.parquet'
# Table 'repair_action' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/repair_action.parquet'
# Table 'problem' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/problem.parquet'
# Table 'lexical_problem' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/lexical_problem.parquet'
# Table 'statements' has been exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/statements.parquet'
# All tables have been exported to Parquet files in the specified directory.
# CPU times: user 7min 5s, sys: 1min 42s, total: 8min 47s
# Wall time: 8min 54s

# %%
# %%time
import pandas as pd

# Read the parquet file and display first 200 rows
df = pd.read_parquet('/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/statements.parquet')

# Display first 200 rows
print("First 200 rows:")
print(df.head(200))

# Also display basic information about the dataframe
print("\nDataframe Info:")
print(df.info())
# Out:
# First 200 rows:
#            stanza       subject         predicate        object  \
# 0    obo:envo.owl  obo:envo.owl     foaf:homepage          None
# 1    obo:envo.owl  obo:envo.owl   owl:versionInfo          None
# 2    obo:envo.owl  obo:envo.owl      rdfs:comment          None
# 3    obo:envo.owl  obo:envo.owl      rdfs:comment          None
# 4    obo:envo.owl  obo:envo.owl      rdfs:comment          None
# ..            ...           ...               ...           ...
# 195   IAO:0000425   IAO:0000425        rdfs:label          None
# 196   IAO:0000425   IAO:0000425        rdfs:label          None
# 197   IAO:0000425   IAO:0000425  rdfs:isDefinedBy  obo:envo.owl
# 198   IAO:0000425   IAO:0000425       IAO:0000117          None
# 199   IAO:0000425   IAO:0000425       IAO:0000115          None
#
#                                                  value    datatype language  \
# 0                      http://environmentontology.org/  xsd:anyURI     None
# 1                                           2024-07-01        None     None
# 2    Includes Ontology(OntologyID(OntologyIRI(<http...        None     None
# 3    Includes Ontology(OntologyID(OntologyIRI(<http...        None     None
# 4    Includes Ontology(OntologyID(OntologyIRI(<http...        None     None
# ..                                                 ...         ...      ...
# 195                                expand assertion to        None       en
# 196                                expand assertion to        None     None
# 197                                               None        None     None
# 198                                      Chris Mungall        None       en
# 199  A macro expansion tag applied to an annotation...        None       en
#
#     graph
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 195  None
# 196  None
# 197  None
# 198  None
# 199  None
#
# [200 rows x 8 columns]
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37558125 entries, 0 to 37558124
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   stanza     object
#  1   subject    object
#  2   predicate  object
#  3   object     object
#  4   value      object
#  5   datatype   object
#  6   language   object
#  7   graph      object
# dtypes: object(8)
# memory usage: 2.2+ GB
# None
# CPU times: user 46 s, sys: 29.5 s, total: 1min 15s
# Wall time: 55.2 s

# %%
# %%time
import pandas as pd
import re

# Read the parquet file
df = pd.read_parquet('/scratch/jplfaria/KBase_CDM_Ontologies/outputs/parquet_tables_ontology_data_owl/statements.parquet')

def extract_prefix(value):
    if pd.isna(value):
        return None
    # Match patterns like 'obo:', 'rdfs:', 'owl:', etc.
    match = re.match(r'^([a-zA-Z]+:)', str(value))
    if match:
        return match.group(1)
    return None

# Extract unique prefixes from subject, predicate, and object columns
subject_prefixes = set(df['subject'].apply(extract_prefix).dropna())
predicate_prefixes = set(df['predicate'].apply(extract_prefix).dropna())
object_prefixes = set(df['object'].apply(extract_prefix).dropna())

# Combine all unique prefixes
all_prefixes = sorted(subject_prefixes | predicate_prefixes | object_prefixes)

print("Unique prefixes found in the data:")
for prefix in all_prefixes:
    print(f"- {prefix}")

print("\nTotal number of unique prefixes:", len(all_prefixes))

# Show count of each prefix usage
print("\nPrefix usage counts:")
for column in ['subject', 'predicate', 'object']:
    prefix_counts = df[column].apply(extract_prefix).value_counts()
    print(f"\nTop 10 prefixes in {column} column:")
    print(prefix_counts.head(10))

# %%
# %%time
import os
import pandas as pd

# Input and output directories
input_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl'
output_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/parquet_tables_ontology_data_owl'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Get all TSV files in the input directory
tsv_files = [f for f in os.listdir(input_dir) if f.endswith('.tsv')]

# Convert each TSV file to Parquet
for tsv_file in tsv_files:
    # Construct full file paths
    tsv_path = os.path.join(input_dir, tsv_file)
    parquet_file = tsv_file.replace('.tsv', '.parquet')
    parquet_path = os.path.join(output_dir, parquet_file)
    
    # Read TSV and write to Parquet
    try:
        df = pd.read_csv(tsv_path, sep='\t')
        df.to_parquet(parquet_path, index=False)
        print(f"Converted '{tsv_file}' to '{parquet_file}'")
    except Exception as e:
        print(f"Error converting {tsv_file}: {str(e)}")

print("\nConversion complete! All TSV files have been converted to Parquet format.")
# Out:
# Converted 'term_association.tsv' to 'term_association.parquet'
# Converted 'has_oio_synonym_statement.tsv' to 'has_oio_synonym_statement.parquet'
# Converted 'anonymous_expression.tsv' to 'anonymous_expression.parquet'
# Converted 'anonymous_class_expression.tsv' to 'anonymous_class_expression.parquet'
# Converted 'anonymous_property_expression.tsv' to 'anonymous_property_expression.parquet'
# Converted 'anonymous_individual_expression.tsv' to 'anonymous_individual_expression.parquet'
# Converted 'owl_restriction.tsv' to 'owl_restriction.parquet'
# Converted 'owl_complex_axiom.tsv' to 'owl_complex_axiom.parquet'
# Converted 'prefix.tsv' to 'prefix.parquet'
# Converted 'rdf_list_statement.tsv' to 'rdf_list_statement.parquet'
# Converted 'rdf_level_summary_statistic.tsv' to 'rdf_level_summary_statistic.parquet'
# Converted 'relation_graph_construct.tsv' to 'relation_graph_construct.parquet'
# Converted 'subgraph_query.tsv' to 'subgraph_query.parquet'
# Converted 'entailed_edge.tsv' to 'entailed_edge.parquet'
# Converted 'repair_action.tsv' to 'repair_action.parquet'
# Converted 'problem.tsv' to 'problem.parquet'
# Converted 'lexical_problem.tsv' to 'lexical_problem.parquet'
# <timed exec>:23: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
# Converted 'statements.tsv' to 'statements.parquet'
#
# Conversion complete! All TSV files have been converted to Parquet format.
# CPU times: user 4min 31s, sys: 50.7 s, total: 5min 21s
# Wall time: 5min 59s

# %%
# %%time
import os
import sqlite3
import pandas as pd
#Specify the output directory
output_dir = '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Connect to the SQLite database
conn = sqlite3.connect('/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/eccode.db')

# Get a list of all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Extract each table and save as TSV
for table in tables:
    table_name = table[0]
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    output_path = os.path.join(output_dir, f"{table_name}.tsv")
    df.to_csv(output_path, sep='\t', index=False)
    print(f"Table '{table_name}' has been exported to '{output_path}'")

# Close the connection
conn.close()
print("All tables have been exported to TSV files in the specified directory.")
# Out:
# Table 'term_association' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/term_association.tsv'
# Table 'has_oio_synonym_statement' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/has_oio_synonym_statement.tsv'
# Table 'anonymous_expression' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/anonymous_expression.tsv'
# Table 'anonymous_class_expression' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/anonymous_class_expression.tsv'
# Table 'anonymous_property_expression' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/anonymous_property_expression.tsv'
# Table 'anonymous_individual_expression' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/anonymous_individual_expression.tsv'
# Table 'owl_restriction' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/owl_restriction.tsv'
# Table 'owl_complex_axiom' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/owl_complex_axiom.tsv'
# Table 'prefix' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/prefix.tsv'
# Table 'rdf_list_statement' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/rdf_list_statement.tsv'
# Table 'rdf_level_summary_statistic' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/rdf_level_summary_statistic.tsv'
# Table 'relation_graph_construct' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/relation_graph_construct.tsv'
# Table 'subgraph_query' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/subgraph_query.tsv'
# Table 'entailed_edge' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/entailed_edge.tsv'
# Table 'repair_action' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/repair_action.tsv'
# Table 'problem' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/problem.tsv'
# Table 'lexical_problem' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/lexical_problem.tsv'
# Table 'statements' has been exported to '/cdm_shared_workspace/user_shared_workspace/Jose/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl_ec/statements.tsv'
# All tables have been exported to TSV files in the specified directory.
# CPU times: user 1min 50s, sys: 0 ns, total: 1min 50s
# Wall time: 1min 49s

# %%
# %%time
import os
import sqlite3
import pandas as pd

def export_database_objects(db_path, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get both tables and views
    cursor.execute("""
        SELECT name, type 
        FROM sqlite_master 
        WHERE type IN ('table', 'view')
        AND name NOT LIKE 'sqlite_%';
    """)
    
    db_objects = cursor.fetchall()
    
    # Extract each object and save as TSV
    for obj_name, obj_type in db_objects:
        try:
            df = pd.read_sql_query(f"SELECT * FROM {obj_name}", conn)
            output_path = os.path.join(output_dir, f"{obj_name}_{obj_type}.tsv")
            df.to_csv(output_path, sep='\t', index=False)
            print(f"{obj_type.capitalize()} '{obj_name}' exported to '{output_path}'")
            print(f"Number of rows: {len(df)}")
        except Exception as e:
            print(f"Error processing {obj_type} {obj_name}: {str(e)}")
    
    conn.close()
    print("\nExport complete!")

# Usage
db_path = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.db'
output_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl'

export_database_objects(db_path, output_dir)
# Out:
# Table 'term_association' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/term_association_table.tsv'
# Number of rows: 0
# Table 'has_oio_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_oio_synonym_statement_table.tsv'
# Number of rows: 0
# Table 'anonymous_expression' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_expression_table.tsv'
# Number of rows: 0
# Table 'anonymous_class_expression' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_class_expression_table.tsv'
# Number of rows: 0
# Table 'anonymous_property_expression' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_property_expression_table.tsv'
# Number of rows: 0
# Table 'anonymous_individual_expression' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_individual_expression_table.tsv'
# Number of rows: 0
# Table 'owl_restriction' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_restriction_table.tsv'
# Number of rows: 0
# Table 'owl_complex_axiom' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_complex_axiom_table.tsv'
# Number of rows: 0
# Table 'prefix' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/prefix_table.tsv'
# Number of rows: 1120
# Table 'rdf_list_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/rdf_list_statement_table.tsv'
# Number of rows: 0
# Table 'rdf_level_summary_statistic' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/rdf_level_summary_statistic_table.tsv'
# Number of rows: 0
# Table 'relation_graph_construct' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/relation_graph_construct_table.tsv'
# Number of rows: 0
# Table 'subgraph_query' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/subgraph_query_table.tsv'
# Number of rows: 0
# Table 'entailed_edge' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/entailed_edge_table.tsv'
# Number of rows: 117371459
# Table 'repair_action' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/repair_action_table.tsv'
# Number of rows: 0
# Table 'problem' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/problem_table.tsv'
# Number of rows: 0
# Table 'lexical_problem' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/lexical_problem_table.tsv'
# Number of rows: 0
# View 'has_text_definition_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_text_definition_statement_view.tsv'
# Number of rows: 318857
# View 'has_exact_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_exact_synonym_statement_view.tsv'
# Number of rows: 373387
# View 'has_broad_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_broad_synonym_statement_view.tsv'
# Number of rows: 9499
# View 'has_narrow_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_narrow_synonym_statement_view.tsv'
# Number of rows: 22726
# View 'has_related_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_related_synonym_statement_view.tsv'
# Number of rows: 567139
# View 'has_synonym_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_synonym_statement_view.tsv'
# Number of rows: 972750
# View 'has_exact_match_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_exact_match_statement_view.tsv'
# Number of rows: 0
# View 'has_broad_match_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_broad_match_statement_view.tsv'
# Number of rows: 0
# View 'has_narrow_match_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_narrow_match_statement_view.tsv'
# Number of rows: 0
# View 'has_related_match_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_related_match_statement_view.tsv'
# Number of rows: 0
# View 'has_match_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_match_statement_view.tsv'
# Number of rows: 0
# View 'has_dbxref_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_dbxref_statement_view.tsv'
# Number of rows: 4072750
# View 'has_mapping_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_mapping_statement_view.tsv'
# Number of rows: 4072750
# View 'contributor' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/contributor_view.tsv'
# Number of rows: 13931
# View 'creator' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/creator_view.tsv'
# Number of rows: 98
# View 'orcid' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/orcid_view.tsv'
# Number of rows: 0
# View 'axiom_dbxref_annotation' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/axiom_dbxref_annotation_view.tsv'
# Number of rows: 636653
# View 'ontology_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/ontology_node_view.tsv'
# Number of rows: 1
# View 'object_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/object_property_node_view.tsv'
# Number of rows: 839
# View 'transitive_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/transitive_property_node_view.tsv'
# Number of rows: 56
# View 'symmetric_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/symmetric_property_node_view.tsv'
# Number of rows: 89
# View 'reflexive_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/reflexive_property_node_view.tsv'
# Number of rows: 2
# View 'irreflexive_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/irreflexive_property_node_view.tsv'
# Number of rows: 0
# View 'asymmetric_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/asymmetric_property_node_view.tsv'
# Number of rows: 2
# View 'annotation_property_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/annotation_property_node_view.tsv'
# Number of rows: 432
# View 'deprecated_node' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/deprecated_node_view.tsv'
# Number of rows: 37097
# View 'owl_imports_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_imports_statement_view.tsv'
# Number of rows: 0
# View 'owl_inverse_of_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_inverse_of_statement_view.tsv'
# Number of rows: 139
# View 'owl_complement_of_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_complement_of_statement_view.tsv'
# Number of rows: 238
# View 'owl_equivalent_class_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_equivalent_class_statement_view.tsv'
# Number of rows: 25229
# View 'owl_same_as_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_same_as_statement_view.tsv'
# Number of rows: 0
# View 'owl_disjoint_class_statement' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_disjoint_class_statement_view.tsv'
# Number of rows: 0
# View 'owl_reified_axiom' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_reified_axiom_view.tsv'
# Number of rows: 1190629
# Error processing view owl_axiom: Execution failed on sql 'SELECT * FROM owl_axiom': SELECTs to the left and right of UNION do not have the same number of result columns
# View 'owl_axiom_annotation' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_axiom_annotation_view.tsv'
# Number of rows: 1394483
# View 'owl_some_values_from' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_some_values_from_view.tsv'
# Number of rows: 1670200
# View 'owl_all_values_from' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_all_values_from_view.tsv'
# Number of rows: 328
# View 'owl_has_value' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_has_value_view.tsv'
# Number of rows: 134
# View 'owl_has_self' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_has_self_view.tsv'
# Number of rows: 1
# View 'owl_subclass_of_some_values_from' exported to '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_subclass_of_some_values_from_view.tsv'
# Number of rows: 1635417
# Error processing view owl_equivalent_to_intersection_member: Execution failed on sql 'SELECT * FROM owl_equivalent_to_intersection_member': database or disk is full

# %%
import os
import sqlite3
import pandas as pd
import textwrap

def export_database_objects(db_path, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get both tables and views
    cursor.execute("""
        SELECT name, type 
        FROM sqlite_master 
        WHERE type IN ('table', 'view')
        AND name NOT LIKE 'sqlite_%';
    """)
    
    db_objects = cursor.fetchall()
    
    # Extract each object and save as TSV
    for obj_name, obj_type in db_objects:
        try:
            # Read the data into a DataFrame
            df = pd.read_sql_query(f"SELECT * FROM {obj_name}", conn)
            
            # Save to TSV
            output_path = os.path.join(output_dir, f"{obj_name}_{obj_type}.tsv")
            df.to_csv(output_path, sep='\t', index=False)
            
            # Print detailed information
            print("\n" + "="*80)
            print(f"{obj_type.capitalize()}: '{obj_name}'")
            print(f"Number of rows: {len(df)}")
            print("\nColumns:")
            for col in df.columns:
                print(f"- {col}")
                
            if len(df) > 0:
                print("\nFirst row of data:")
                # Format the first row nicely
                first_row = df.iloc[0]
                for col, val in first_row.items():
                    # Wrap long values for better readability
                    if isinstance(val, str) and len(str(val)) > 50:
                        val = textwrap.shorten(str(val), width=50, placeholder="...")
                    print(f"  {col}: {val}")
            else:
                print("\nNo data in this table/view")
            
            print(f"\nExported to: {output_path}")
            
        except Exception as e:
            print(f"Error processing {obj_type} {obj_name}: {str(e)}")
    
    conn.close()
    print("\nExport complete!")

# Usage
db_path = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/ontology_data_owl.db'
output_dir = '/scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl'

export_database_objects(db_path, output_dir)
# Out:
# ================================================================================
# Table: 'term_association'
# Number of rows: 0
#
# Columns:
# - id
# - subject
# - predicate
# - object
# - evidence_type
# - publication
# - source
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/term_association_table.tsv
#
# ================================================================================
# Table: 'has_oio_synonym_statement'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_oio_synonym_statement_table.tsv
#
# ================================================================================
# Table: 'anonymous_expression'
# Number of rows: 0
#
# Columns:
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_expression_table.tsv
#
# ================================================================================
# Table: 'anonymous_class_expression'
# Number of rows: 0
#
# Columns:
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_class_expression_table.tsv
#
# ================================================================================
# Table: 'anonymous_property_expression'
# Number of rows: 0
#
# Columns:
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_property_expression_table.tsv
#
# ================================================================================
# Table: 'anonymous_individual_expression'
# Number of rows: 0
#
# Columns:
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/anonymous_individual_expression_table.tsv
#
# ================================================================================
# Table: 'owl_restriction'
# Number of rows: 0
#
# Columns:
# - on_property
# - filler
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_restriction_table.tsv
#
# ================================================================================
# Table: 'owl_complex_axiom'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - object
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_complex_axiom_table.tsv
#
# ================================================================================
# Table: 'prefix'
# Number of rows: 1120
#
# Columns:
# - prefix
# - base
#
# First row of data:
#   prefix: prefix
#   base: base
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/prefix_table.tsv
#
# ================================================================================
# Table: 'rdf_list_statement'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/rdf_list_statement_table.tsv
#
# ================================================================================
# Table: 'rdf_level_summary_statistic'
# Number of rows: 0
#
# Columns:
# - element
# - count_value
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/rdf_level_summary_statistic_table.tsv
#
# ================================================================================
# Table: 'relation_graph_construct'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - object
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/relation_graph_construct_table.tsv
#
# ================================================================================
# Table: 'subgraph_query'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - object
# - anchor_object
# - anchor_predicate
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/subgraph_query_table.tsv
#
# ================================================================================
# Table: 'entailed_edge'
# Number of rows: 117371459
#
# Columns:
# - subject
# - predicate
# - object
#
# First row of data:
#   subject: CHEBI:165710
#   predicate: rdfs:subClassOf
#   object: CHEBI:165710
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/entailed_edge_table.tsv
#
# ================================================================================
# Table: 'repair_action'
# Number of rows: 0
#
# Columns:
# - subject
# - description
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/repair_action_table.tsv
#
# ================================================================================
# Table: 'problem'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - value
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/problem_table.tsv
#
# ================================================================================
# Table: 'lexical_problem'
# Number of rows: 0
#
# Columns:
# - subject
# - predicate
# - value
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/lexical_problem_table.tsv
#
# ================================================================================
# View: 'has_text_definition_statement'
# Number of rows: 318857
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: BFO:0000179
#   subject: BFO:0000179
#   predicate: IAO:0000115
#   object: None
#   value: Relates an entity in the ontology to the name...
#   datatype: None
#   language: en
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_text_definition_statement_view.tsv
#
# ================================================================================
# View: 'has_exact_synonym_statement'
# Number of rows: 373387
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: OMO:0003010
#   subject: OMO:0003010
#   predicate: oio:hasExactSynonym
#   object: None
#   value: INN
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_exact_synonym_statement_view.tsv
#
# ================================================================================
# View: 'has_broad_synonym_statement'
# Number of rows: 9499
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: RO:0002374
#   subject: RO:0002374
#   predicate: oio:hasBroadSynonym
#   object: None
#   value: has fused element
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_broad_synonym_statement_view.tsv
#
# ================================================================================
# View: 'has_narrow_synonym_statement'
# Number of rows: 22726
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: RO:0002553
#   subject: RO:0002553
#   predicate: oio:hasNarrowSynonym
#   object: None
#   value: hyperparasitoid of
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_narrow_synonym_statement_view.tsv
#
# ================================================================================
# View: 'has_related_synonym_statement'
# Number of rows: 567139
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: RO:0002248
#   subject: RO:0002248
#   predicate: oio:hasRelatedSynonym
#   object: None
#   value: has active pharmaceutical ingredient
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_related_synonym_statement_view.tsv
#
# ================================================================================
# View: 'has_synonym_statement'
# Number of rows: 972750
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: <https://bioregistry.io/eccode:1.1.1.101>
#   subject: <https://bioregistry.io/eccode:1.1.1.101>
#   predicate: oio:hasExactSynonym
#   object: None
#   value: palmitoyldihydroxyacetone-phosphate reductase
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_synonym_statement_view.tsv
#
# ================================================================================
# View: 'has_exact_match_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_exact_match_statement_view.tsv
#
# ================================================================================
# View: 'has_broad_match_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_broad_match_statement_view.tsv
#
# ================================================================================
# View: 'has_narrow_match_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_narrow_match_statement_view.tsv
#
# ================================================================================
# View: 'has_related_match_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_related_match_statement_view.tsv
#
# ================================================================================
# View: 'has_match_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_match_statement_view.tsv
#
# ================================================================================
# View: 'has_dbxref_statement'
# Number of rows: 4072750
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: IAO:0000233
#   subject: IAO:0000233
#   predicate: oio:hasDbXref
#   object: None
#   value: IAO:0000233
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_dbxref_statement_view.tsv
#
# ================================================================================
# View: 'has_mapping_statement'
# Number of rows: 4072750
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: <https://purl.obolibrary.org/obo/PCO_0000040>
#   subject: <https://purl.obolibrary.org/obo/PCO_0000040>
#   predicate: oio:hasDbXref
#   object: None
#   value: ...
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/has_mapping_statement_view.tsv
#
# ================================================================================
# View: 'contributor'
# Number of rows: 13931
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: obo:foodon.owl
#   subject: obo:foodon.owl
#   predicate: dcterms:contributor
#   object: None
#   value: Rhiannon Cameron
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/contributor_view.tsv
#
# ================================================================================
# View: 'creator'
# Number of rows: 98
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: RO:0002575
#   subject: RO:0002575
#   predicate: dcterms:creator
#   object: orcid:0000-0002-6601-2165
#   value: None
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/creator_view.tsv
#
# ================================================================================
# View: 'orcid'
# Number of rows: 0
#
# Columns:
# - id
# - label
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/orcid_view.tsv
#
# ================================================================================
# View: 'axiom_dbxref_annotation'
# Number of rows: 636653
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - id
# - annotation_subject
# - annotation_predicate
# - annotation_object
# - annotation_value
# - annotation_language
# - annotation_datatype
#
# First row of data:
#   stanza: obo:UBPROP_0000001
#   subject: obo:UBPROP_0000001
#   predicate: IAO:0000115
#   object: None
#   value: An alternate textual definition for a class...
#   datatype: None
#   language: None
#   id: _:riog00000125
#   annotation_subject: _:riog00000125
#   annotation_predicate: oio:hasDbXref
#   annotation_object: None
#   annotation_value: https://orcid.org/0000-0002-6601-2165
#   annotation_language: None
#   annotation_datatype: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/axiom_dbxref_annotation_view.tsv
#
# ================================================================================
# View: 'ontology_node'
# Number of rows: 1
#
# Columns:
# - id
#
# First row of data:
#   id: obo:foodon.owl
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/ontology_node_view.tsv
#
# ================================================================================
# View: 'object_property_node'
# Number of rows: 839
#
# Columns:
# - id
#
# First row of data:
#   id: BFO:0000050
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/object_property_node_view.tsv
#
# ================================================================================
# View: 'transitive_property_node'
# Number of rows: 56
#
# Columns:
# - id
#
# First row of data:
#   id: BFO:0000050
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/transitive_property_node_view.tsv
#
# ================================================================================
# View: 'symmetric_property_node'
# Number of rows: 89
#
# Columns:
# - id
#
# First row of data:
#   id: FOODON:00001301
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/symmetric_property_node_view.tsv
#
# ================================================================================
# View: 'reflexive_property_node'
# Number of rows: 2
#
# Columns:
# - id
#
# First row of data:
#   id: RO:0002351
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/reflexive_property_node_view.tsv
#
# ================================================================================
# View: 'irreflexive_property_node'
# Number of rows: 0
#
# Columns:
# - id
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/irreflexive_property_node_view.tsv
#
# ================================================================================
# View: 'asymmetric_property_node'
# Number of rows: 2
#
# Columns:
# - id
#
# First row of data:
#   id: RO:0002551
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/asymmetric_property_node_view.tsv
#
# ================================================================================
# View: 'annotation_property_node'
# Number of rows: 432
#
# Columns:
# - id
#
# First row of data:
#   id: <http://geneontology.org/foo/applies-pattern>
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/annotation_property_node_view.tsv
#
# ================================================================================
# View: 'deprecated_node'
# Number of rows: 37097
#
# Columns:
# - id
#
# First row of data:
#   id: BFO:0000060
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/deprecated_node_view.tsv
#
# ================================================================================
# View: 'owl_imports_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_imports_statement_view.tsv
#
# ================================================================================
# View: 'owl_inverse_of_statement'
# Number of rows: 139
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: BFO:0000050
#   subject: BFO:0000050
#   predicate: owl:inverseOf
#   object: BFO:0000051
#   value: None
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_inverse_of_statement_view.tsv
#
# ================================================================================
# View: 'owl_complement_of_statement'
# Number of rows: 238
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: IAO:0000583
#   subject: _:riog00000573
#   predicate: owl:complementOf
#   object: IAO:0000416
#   value: None
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_complement_of_statement_view.tsv
#
# ================================================================================
# View: 'owl_equivalent_class_statement'
# Number of rows: 25229
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# First row of data:
#   stanza: BFO:0000023
#   subject: BFO:0000023
#   predicate: owl:equivalentClass
#   object: CHEBI:50906
#   value: None
#   datatype: None
#   language: None
#   graph: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_equivalent_class_statement_view.tsv
#
# ================================================================================
# View: 'owl_same_as_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_same_as_statement_view.tsv
#
# ================================================================================
# View: 'owl_disjoint_class_statement'
# Number of rows: 0
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - graph
#
# No data in this table/view
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_disjoint_class_statement_view.tsv
#
# ================================================================================
# View: 'owl_reified_axiom'
# Number of rows: 1190629
#
# Columns:
# - id
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
#
# First row of data:
#   id: _:riog00000125
#   stanza: obo:UBPROP_0000001
#   subject: obo:UBPROP_0000001
#   predicate: IAO:0000115
#   object: None
#   value: An alternate textual definition for a class...
#   datatype: None
#   language: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_reified_axiom_view.tsv
# Error processing view owl_axiom: Execution failed on sql 'SELECT * FROM owl_axiom': SELECTs to the left and right of UNION do not have the same number of result columns
#
# ================================================================================
# View: 'owl_axiom_annotation'
# Number of rows: 1394483
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
# - value
# - datatype
# - language
# - id
# - annotation_subject
# - annotation_predicate
# - annotation_object
# - annotation_value
# - annotation_language
# - annotation_datatype
#
# First row of data:
#   stanza: obo:UBPROP_0000001
#   subject: obo:UBPROP_0000001
#   predicate: IAO:0000115
#   object: None
#   value: An alternate textual definition for a class...
#   datatype: None
#   language: None
#   id: _:riog00000125
#   annotation_subject: _:riog00000125
#   annotation_predicate: oio:hasDbXref
#   annotation_object: None
#   annotation_value: https://orcid.org/0000-0002-6601-2165
#   annotation_language: None
#   annotation_datatype: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_axiom_annotation_view.tsv
#
# ================================================================================
# View: 'owl_some_values_from'
# Number of rows: 1670200
#
# Columns:
# - id
# - on_property
# - filler
#
# First row of data:
#   id: _:riog00000637
#   on_property: RO:0000087
#   filler: OBI:0000202
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_some_values_from_view.tsv
#
# ================================================================================
# View: 'owl_all_values_from'
# Number of rows: 328
#
# Columns:
# - id
# - on_property
# - filler
#
# First row of data:
#   id: _:riog00002313
#   on_property: BFO:0000050
#   filler: BFO:0000002
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_all_values_from_view.tsv
#
# ================================================================================
# View: 'owl_has_value'
# Number of rows: 134
#
# Columns:
# - id
# - on_property
# - filler
#
# First row of data:
#   id: _:riog04243142
#   on_property: OBI:0000304
#   filler: OBI:0000758
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_has_value_view.tsv
#
# ================================================================================
# View: 'owl_has_self'
# Number of rows: 1
#
# Columns:
# - id
# - on_property
# - filler
#
# First row of data:
#   id: _:riog01057611
#   on_property: RO:0002481
#   filler: None
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_has_self_view.tsv
#
# ================================================================================
# View: 'owl_subclass_of_some_values_from'
# Number of rows: 1635417
#
# Columns:
# - stanza
# - subject
# - predicate
# - object
#
# First row of data:
#   stanza: CARO:0000014
#   subject: CARO:0000014
#   predicate: BFO:0000050
#   object: CARO:0000013
#
# Exported to: /scratch/jplfaria/KBase_CDM_Ontologies/outputs/tsv_tables_ontology_data_owl/owl_subclass_of_some_values_from_view.tsv
